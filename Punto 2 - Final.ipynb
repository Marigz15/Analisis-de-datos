# %% [markdown]
# María Giraldo Zuluaga

# %%
#IMPORTAR LIBRERÍAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import random
from deap import base, creator, tools, algorithms

import warnings
warnings.filterwarnings('ignore')

# %%
#Importar los datos
portafolio1 = ['AMZN', 'TSLA', 'AAPL', 'QCOM', 'META', 'NFLX']
portafolio2 = ['MRVL', 'AI', 'GE', 'NVDA']
datos = pd.DataFrame()
for p1 in portafolio1:
    datos[p1] = yf.download(p1, start = '2020-01-01')['Adj Close']
for p2 in portafolio2:
    datos[p2] = yf.download(p2, start = '2020-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
datos.plot(figsize = (20, 8))
plt.show()

# %%
#IMPLEMENTACIÓN DEL ALGORITMO EVOLUTIVO 1
#Función de adaptabilidad
def evaluarPortafolio1 (individuo1, retorno1): 
    pesos1 = np.array(individuo1) / np.sum(individuo1)
    retornoPortafolio1 = np.dot((retornoLog.mean() * 250), pesos1)
    volatilidadPortafolio1 = np.sqrt(np.dot(pesos1.T, np.dot((retornoLog.cov())* 250), pesos1))
    return retornoPortafolio1, - volatilidadPortafolio1,

# %%
#IMPLEMENTACIÓN DEL ALGORITMO EVOLUTIVO
#Función de adaptabilidad
def evaluarPortafolio2 (individuo2, retorno2): 
    pesos2 = np.array(individuo2) / np.sum(individuo2)
    retornoPortafolio2 = np.dot((retornoLog.mean() * 250), pesos)
    volatilidadPortafolio2 = np.sqrt(np.dot(pesos2.T, np.dot((retornoLog.cov())* 250), pesos2))
    return retornoPortafolio2, - volatilidadPortafolio2,

# %%
#Configuración
toolbox = base.Toolbox()
creator.create('FitnessMax', base.Fitness, weight = (1.0, 1.0))
creator.create('Individual', list, fitness = creator.FitnessMax)

# %%
toolbox.register('attribute', random.uniform, 0.1)
toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.attribute, n = 4)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)

# %%
#toolbox.register('evaluate', evaluarPortafolio1, retorno1 = retornoLog)
#toolbox.register('select', tools.selTournament, tournsize = 3)
#toolbox.register('mate', tools.cxUniform, indpb = 0.5)
#toolbox.register('mutate', tools.mutUniformInt, low = 0, up = 1, indpb = 0.1)

# %%
#Parámetros
tamañoPoblacion1 = 100
probMutacion = 0.1
cantGeneracion = 50

# %%
#Generación de la población inicial
poblacion1 = []
for _ in range (tamañoPoblacion1):
    individuo = [random.choice()]
    poblacion.append(individuo1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11752\912961272.py in <module>
#       2 poblacion1 = []
#       3 for _ in range (tamañoPoblacion1):
# ----> 4     individuo = [random.choice()]
#       5     poblacion.append(individuo1)
#
# TypeError: choice() missing 1 required positional argument: 'seq'
